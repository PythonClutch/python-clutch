# %%
today = datetime.utcnow()

# %%
age_years = today - timedelta(days=3*365)

# %%
age_months = today - timedelta(days=60)

# %%
age_weeks = today - timedelta(days=14)

# %%
age_weeks
# Out:
# datetime.datetime(2015, 3, 6, 18, 35, 25, 434350)

# %%
today = datetime.utcnow()
diff = today - age_years

# %%
diff
# Out:
# datetime.timedelta(1095, 996, 349058)

# %%
import arrow

# %%
now = arrow.utcnow()

# %%
now.humanize()
# Out:
# 'just now'

# %%
age = arrow.get('2009-10-19 23:22:02')

# %%
age.humanize()
# Out:
# '5 years ago'

# %%
http://pypi.python.org/pypi/virtualenv 
http://pypi.python.org/pypi/setuptools
http://pypi.python.org/pypi/certifi
http://pypi.python.org/pypi/requests

http://pypi.python.org/pypi/boto

http://pypi.python.org/pypi/wincertstore

http://pypi.python.org/pypi/pip

http://pypi.python.org/pypi/six

http://pypi.python.org/pypi/pbr

http://pypi.python.org/pypi/python-dateutil

http://pypi.python.org/pypi/lxml

http://pypi.python.org/pypi/nose

http://pypi.python.org/pypi/simplejson

http://pypi.python.org/pypi/pika

http://pypi.python.org/pypi/Jinja2

http://pypi.python.org/pypi/MarkupSafe

http://pypi.python.org/pypi/docutils

http://pypi.python.org/pypi/pytz

http://pypi.python.org/pypi/PyYAML

http://pypi.python.org/pypi/Django

http://pypi.python.org/pypi/psycopg2

http://pypi.python.org/pypi/pyasn1

http://pypi.python.org/pypi/pycrypto

http://pypi.python.org/pypi/coverage

http://pypi.python.org/pypi/zc.buildout

http://pypi.python.org/pypi/paramiko

http://pypi.python.org/pypi/Paste

http://pypi.python.org/pypi/ssl

http://pypi.python.org/pypi/supervisor

http://pypi.python.org/pypi/SQLAlchemy

http://pypi.python.org/pypi/sqlalchemy-migrate

http://pypi.python.org/pypi/botocore

http://pypi.python.org/pypi/colorama

http://pypi.python.org/pypi/selenium

http://pypi.python.org/pypi/rsa

http://pypi.python.org/pypi/awscli

http://pypi.python.org/pypi/jmespath

http://pypi.python.org/pypi/meld3

http://pypi.python.org/pypi/bcdoc

http://pypi.python.org/pypi/redis

http://pypi.python.org/pypi/ecdsa

http://pypi.python.org/pypi/Werkzeug

http://pypi.python.org/pypi/PasteDeploy

http://pypi.python.org/pypi/carbon

http://pypi.python.org/pypi/cffi

http://pypi.python.org/pypi/Flask

http://pypi.python.org/pypi/MySQL-python

http://pypi.python.org/pypi/pymongo

http://pypi.python.org/pypi/graphite-web

http://pypi.python.org/pypi/httplib2

http://pypi.python.org/pypi/mock

http://pypi.python.org/pypi/pep8

http://pypi.python.org/pypi/pycparser

http://pypi.python.org/pypi/greenlet

http://pypi.python.org/pypi/Fabric

http://pypi.python.org/pypi/anyjson

http://pypi.python.org/pypi/Pygments

http://pypi.python.org/pypi/kombu

http://pypi.python.org/pypi/setuptools-git

http://pypi.python.org/pypi/zope.interface

http://pypi.python.org/pypi/beautifulsoup4

http://pypi.python.org/pypi/py

http://pypi.python.org/pypi/itsdangerous

http://pypi.python.org/pypi/docopt

http://pypi.python.org/pypi/South

http://pypi.python.org/pypi/Pillow

http://pypi.python.org/pypi/celery

http://pypi.python.org/pypi/Mako

http://pypi.python.org/pypi/Babel

http://pypi.python.org/pypi/tornado

http://pypi.python.org/pypi/WebOb

http://pypi.python.org/pypi/gunicorn

http://pypi.python.org/pypi/isodate

http://pypi.python.org/pypi/iso8601

http://pypi.python.org/pypi/pyOpenSSL

http://pypi.python.org/pypi/billiard

http://pypi.python.org/pypi/ordereddict

http://pypi.python.org/pypi/amqp

http://pypi.python.org/pypi/gevent

http://pypi.python.org/pypi/logilab-common

http://pypi.python.org/pypi/pycups

http://pypi.python.org/pypi/PrettyTable

http://pypi.python.org/pypi/pyflakes

http://pypi.python.org/pypi/numpy

http://pypi.python.org/pypi/psutil

http://pypi.python.org/pypi/Sphinx

http://pypi.python.org/pypi/pylint

http://pypi.python.org/pypi/argparse

http://pypi.python.org/pypi/pyparsing

http://pypi.python.org/pypi/Twisted

http://pypi-ranking.info/module/stevedore

http://pypi.python.org/pypi/cryptography

http://pypi.python.org/pypi/decorator

http://pypi.python.org/pypi/pytest

http://pypi.python.org/pypi/flake8

http://pypi.python.org/pypi/mccabe

http://pypi.python.org/pypi/PasteScript

http://pypi.python.org/pypi/suds

http://pypi.python.org/pypi/oslo.config

http://pypi.python.org/pypi/urllib3

http://pypi.python.org/pypi/python-daemon

http://pypi.python.org/pypi/ipython

http://pypi.python.org/pypi/Cython

http://pypi.python.org/pypi/raven

http://pypi.python.org/pypi/msgpack-python

http://pypi.python.org/pypi/BeautifulSoup

http://pypi.python.org/pypi/unittest2

http://pypi.python.org/pypi/eventlet

http://pypi.python.org/pypi/rdflib

http://pypi.python.org/pypi/Markdown

http://pypi-ranking.info/module/ujson

http://pypi.python.org/pypi/oauthlib

http://pypi.python.org/pypi/oauth2

http://pypi.python.org/pypi/python-novaclient

http://pypi.python.org/pypi/tox

http://pypi.python.org/pypi/python-keystoneclient

http://pypi.python.org/pypi/user-agents

http://pypi.python.org/pypi/zc.recipe.egg

http://pypi.python.org/pypi/html5lib

http://pypi.python.org/pypi/SPARQLWrapper

http://pypi.python.org/pypi/thrift

http://pypi.python.org/pypi/backports.ssl_match_hostname

http://pypi.python.org/pypi/pygeoip

http://pypi.python.org/pypi/pycurl

http://pypi.python.org/pypi/d2to1

http://pypi.python.org/pypi/astroid

http://pypi.python.org/pypi/repoze.lru

http://pypi.python.org/pypi/WebTest

http://pypi.python.org/pypi/django-debug-toolbar

http://pypi.python.org/pypi/python-swiftclient

http://pypi.python.org/pypi/netaddr

http://pypi.python.org/pypi/django-extensions

http://pypi.python.org/pypi/django-celery

http://pypi.python.org/pypi/versiontools

http://pypi.python.org/pypi/Unidecode

http://pypi.python.org/pypi/futures

http://pypi.python.org/pypi/amqplib

http://pypi.python.org/pypi/jsonschema

http://pypi.python.org/pypi/python-cjson

http://pypi.python.org/pypi/wheel

http://pypi.python.org/pypi/python-mimeparse

http://pypi.python.org/pypi/mrjob

http://pypi.python.org/pypi/django_compressor

http://pypi.python.org/pypi/chardet

http://pypi.python.org/pypi/newrelic

http://pypi.python.org/pypi/waitress

http://pypi.python.org/pypi/cmd2

http://pypi.python.org/pypi/coveralls

http://pypi.python.org/pypi/cov-core

http://pypi.python.org/pypi/python-memcached

http://pypi.python.org/pypi/django-nose

http://pypi.python.org/pypi/testtools

http://pypi.python.org/pypi/ua-parser

http://pypi.python.org/pypi/cliff

http://pypi.python.org/pypi/pystache

http://pypi.python.org/pypi/alembic

http://pypi.python.org/pypi/demjson

http://pypi.python.org/pypi/djangorestframework

http://pypi.python.org/pypi/extras

http://pypi.python.org/pypi/blinker

http://pypi.python.org/pypi/logilab-astng

http://pypi.python.org/pypi/pyzmq

http://pypi.python.org/pypi/apache-libcloud

http://pypi.python.org/pypi/scipy

http://pypi.python.org/pypi/statsd

http://pypi.python.org/pypi/sh

http://pypi.python.org/pypi/warlock

http://pypi.python.org/pypi/nosexcover

http://pypi.python.org/pypi/xlrd

http://pypi.python.org/pypi/Tempita

http://pypi.python.org/pypi/protobuf

http://pypi.python.org/pypi/keyring

http://pypi.python.org/pypi/passlib

http://pypi.python.org/pypi/scikit-learn

http://pypi.python.org/pypi/Beaker

http://pypi.python.org/pypi/tendenci

http://pypi.python.org/pypi/helper

http://pypi.python.org/pypi/rosinstall

http://pypi.python.org/pypi/cssselect

http://pypi.python.org/pypi/youtube_dl

http://pypi.python.org/pypi/python-ldap

http://pypi.python.org/pypi/argh

http://pypi.python.org/pypi/fixtures

http://pypi.python.org/pypi/pandas

http://pypi.python.org/pypi/termcolor

http://pypi.python.org/pypi/enum34

http://pypi-ranking.info/module/python-gflags

http://pypi.python.org/pypi/iptools

http://pypi.python.org/pypi/matplotlib

http://pypi.python.org/pypi/python-subunit

http://pypi.python.org/pypi/sqlparse

http://pypi.python.org/pypi/pyramid

http://pypi.python.org/pypi/jsonpatch

http://pypi.python.org/pypi/jsonpointer

http://pypi.python.org/pypi/Routes

http://pypi.python.org/pypi/minitage.paste

http://pypi.python.org/pypi/django-mptt

http://pypi.python.org/pypi/hiredis

http://pypi.python.org/pypi/zope.deprecation
